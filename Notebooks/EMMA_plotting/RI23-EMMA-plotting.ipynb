# %%
library(fs)
library(ggplot2)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_multi_event_emma_grid.R")) 

wade_sampling_windows <- data.frame(
  start = as.POSIXct(c("2023-02-14 00:00", "2023-03-18 00:00", "2023-03-30 00:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-20 23:59", "2023-03-26 23:59", "2023-04-15 23:59"), tz = "UTC")
)

emma_files_list <- c(
  "~/OneDrive/git-repos/EMMA/Wade_WY23_FebROS_EMMA_fractions.csv",
  "~/OneDrive/git-repos/EMMA/Wade_WY23_MarTherm_EMMA_fractions.csv",
  "~/OneDrive/git-repos/EMMA/Wade_WY23_AprFresh_EMMA_fractions.csv"
)

event_titles_list <- c("February ROS", "March thermal", "Final spring melt")

wade_3x4_grid <- plot_multi_event_grid(
  site_name        = "Wade",
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/Wade_cocorahs-vt-fr-30-20221115-20250414-2.csv"),
  soil_file        = file.path(repo_dir, "Data/SoilSensor_data/Ranch_Brook/RanchBrook_TMS4_WY23_SML1_data.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/wade_2020-2024_met_2024-11-08.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/wb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Wade_Brook.20221001.csv"),
  event_windows_df = wade_sampling_windows,
  emma_files       = emma_files_list,
  event_titles     = event_titles_list,
  q_lim            = c(0, 3.5),
  no3_lim          = c(0, 0.5),
  doc_lim          = c(0, 5),
  snow_lim         = c(0, 50),       
  air_temp_lim     = c(-15, 20),    
  soil_vwc_lim     = c(0.5, 0.6),      
  soil_temp_lim    = c(-2, 8),      
  base_font_size   = 18
)

print(wade_3x4_grid)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Wade_3x4_EMMA_composite.jpg"), 
  plot = wade_3x4_grid, 
  width = 18, 
  height = 14, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 7 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 880 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 946 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 4 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 228 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3575 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 52 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 7 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 5 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 880 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 946 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 4 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 3 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 228 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 3575 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 52 rows containing non-finite outside the scale range (`stat_smooth()`).”
# plot without title

# %%
library(fs)
library(ggplot2)

home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_multi_event_emma_grid.R")) 

hford_sampling_windows <- data.frame(
  start = as.POSIXct(c("2023-02-08 00:00", "2023-03-21 00:00", "2023-03-30 00:00"), tz = "UTC"),
  end   = as.POSIXct(c("2023-02-12 23:59", "2023-03-26 23:59", "2023-04-04 23:59"), tz = "UTC")
)

emma_files_list <- c(
  "~/OneDrive/git-repos/EMMA/Hungerford_WY23_FebROS_EMMA_fractions.csv",
  "~/OneDrive/git-repos/EMMA/Hungerford_WY23_MarTherm_EMMA_fractions.csv",
  "~/OneDrive/git-repos/EMMA/Hungerford_WY23_AprFresh_EMMA_fractions.csv"
)

event_titles_list <- c("February ROS", "March thermal", "Final spring melt")

hungerford_3x4_grid <- plot_multi_event_grid(
  site_name        = "Hungerford",
  q_file           = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  snow_file        = file.path(repo_dir, "Data/Met_data/enf-noaa-precip-WYW23.csv"),
  soil_file        = file.path(repo_dir, "Data/SoilSensor_data", "Swanton_Faulkner/Middle_Teros_brief.csv"),
  met_file         = file.path(repo_dir, "Data/Met_data/hungerford_2020-2024_met_2024-11-08.csv"),
  no3_file         = file.path(repo_dir, "Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv"),
  doc_file         = file.path(repo_dir, "Data/StreamSensor_data/DOC.DOC@Hungerford_Brook.20221001.csv"),
  event_windows_df = hford_sampling_windows,
  emma_files       = emma_files_list,
  event_titles     = event_titles_list,
  q_lim            = c(0, 12),
  no3_lim          = c(0, 8),
  doc_lim          = c(0, 25),
  snow_lim         = c(0, 50),       
  air_temp_lim     = c(-15, 10),    
  soil_vwc_lim     = c(0.2, 0.4),      
  soil_temp_lim    = c(-2, 5),      
  base_font_size   = 18
)

print(hungerford_3x4_grid)

ggsave(
  filename = file.path(repo_dir, "Output/Hydrographs/Hungerford_3x4_EMMA_composite.jpg"), 
  plot = hungerford_3x4_grid, 
  width = 18, 
  height = 14, 
  dpi = 300
)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 157 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 287 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 288 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 157 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 287 rows containing missing values or values outside the scale range (`geom_line()`).”
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 288 rows containing non-finite outside the scale range (`stat_smooth()`).”
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
