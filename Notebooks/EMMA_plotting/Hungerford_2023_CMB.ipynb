# %%
library(fs)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/conductivity_mass_balance.R"))
data_dir <- file.path(repo_dir, "Data/")

# 1. Target Time Windows
my_range  <- as.POSIXct(c("2023-02-10", "2023-04-20"), tz = "UTC")
my_events <- list(
  start = c('2023-02-14', '2023-03-21', '2023-03-30'),
  end   = c('2023-02-20', '2023-03-26', '2023-04-15')
)

# 2. Generate Hydrograph Separation
hungerford_cmb_plot <- plot_stream_cmb(
  site_name    = "Hungerford",
  plot_range   = my_range,
  event_bounds = my_events,
  q_file       = file.path(data_dir, "StreamSensor_data", "hb_q_chem_20211001-20230930.csv"),
  exo_file     = file.path(data_dir, "StreamSensor_data", "hungerford_2023_sC_2024-07-31.csv"),
  q_lim        = c(0, 12),
  sc_lim       = c(0, 500),
  sc_old_val   = 504.3, # Based on Feb 2023 lowest Q period
  sc_new_val   = 12 # Assumed value based on pure rainfall/clean snowmelt
)

print(hungerford_cmb_plot)
# Out:
# Warning message:
# “package ‘fs’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘readr’ was built under R version 4.2.3”
# Warning message:
# “package ‘purrr’ was built under R version 4.2.3”
# Warning message:
# “package ‘dplyr’ was built under R version 4.2.3”
# Warning message:
# “package ‘stringr’ was built under R version 4.2.3”
# Warning message:
# “package ‘forcats’ was built under R version 4.2.3”
# Warning message:
# “package ‘lubridate’ was built under R version 4.2.3”
# ── Attaching core tidyverse packages ────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ...

# %%
library(fs)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/conductivity_mass_balance.R"))
data_dir <- file.path(repo_dir, "Data/")

# Define February event window
feb_window <- as.POSIXct(c("2023-02-08 00:00:00", "2023-02-18 00:00:00"), tz = "UTC")

# Generate the comparison
hungerford_hydrograph_comparison <- plot_emma_vs_cmb_hydrographs(
  site_name      = "Hungerford",
  plot_range     = feb_window,
  q_file       = file.path(data_dir, "StreamSensor_data", "hb_q_chem_20211001-20230930.csv"),
  exo_file     = file.path(data_dir, "StreamSensor_data", "hungerford_2023_sC_2024-07-31.csv"),
  emma_frac_file = "/home/millieginty/OneDrive/git-repos/EMMA/Hungerford_WY23_FebROS_EMMA_fractions.csv",
  q_lim          = c(0, 12),
  sc_old_val     = 504.3, # Based on Feb 2023 lowest Q period
  sc_new_val     = 12
)

print(hungerford_hydrograph_comparison)
# Out:
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# plot without title

# %%
library(fs)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/conductivity_mass_balance.R"))
data_dir <- file.path(repo_dir, "Data/")

# Define March event window
mar_window <- as.POSIXct(c("2023-03-21 00:00:00", "2023-03-26 00:00:00"), tz = "UTC")

# Generate the comparison
hungerford_hydrograph_comparison <- plot_emma_vs_cmb_hydrographs(
  site_name      = "Hungerford",
  plot_range     = mar_window,
  q_file       = file.path(data_dir, "StreamSensor_data", "hb_q_chem_20211001-20230930.csv"),
  exo_file     = file.path(data_dir, "StreamSensor_data", "hungerford_2023_sC_2024-07-31.csv"),
  emma_frac_file = "~/OneDrive/git-repos/EMMA/Hungerford_WY23_MarTherm_EMMA_fractions.csv",
  q_lim          = c(0, 10),
  sc_old_val     = 504.3, # Based on Feb 2023 lowest Q period
  sc_new_val     = 12
)

print(hungerford_hydrograph_comparison)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_line()`).”
# Warning message:
# “Removed 1 row containing missing values or values outside the scale range (`geom_point()`).”
# plot without title

# %%
library(fs)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/conductivity_mass_balance.R"))
data_dir <- file.path(repo_dir, "Data/")

# Define March event window
apr_window <- as.POSIXct(c("2023-03-31 00:00:00", "2023-04-04 00:00:00"), tz = "UTC")

# Generate the comparison
hungerford_hydrograph_comparison <- plot_emma_vs_cmb_hydrographs(
  site_name      = "Hungerford",
  plot_range     = apr_window,
  q_file       = file.path(data_dir, "StreamSensor_data", "hb_q_chem_20211001-20230930.csv"),
  exo_file     = file.path(data_dir, "StreamSensor_data", "hungerford_2023_sC_2024-07-31.csv"),
  emma_frac_file = "~/OneDrive/git-repos/EMMA/Hungerford_WY23_AprFresh_EMMA_fractions.csv", 
  q_lim          = c(0, 4), 
  sc_old_val     = 504.3,
  sc_new_val     = 12
)

print(hungerford_hydrograph_comparison)
# Out:
# plot without title
