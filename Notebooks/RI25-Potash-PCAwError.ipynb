# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_pca_error as ep
importlib.reload(ep)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

####################
# Wade RI25 events #
####################

# Event A
# Wade 12/10 ROS event
# Potential endmembers: 
    # "RI25-1126", "RI25-1031", "RI25-1090", "RI25-1183", "RI25-1201", "RI25-1290" 12/06/2024 (good baseflow); potential baseflow 12/10/2024 + 12/28/2024; 03/04/2025; 03/11/2025; 03/03/2025
    # "RI25-1123", "RI25-1115", "RI25-1305" Soil lysimeter dry 12/17/2024; 2/10/2025; 04/04/2024
    # "RI25-1306" Soil water lysimeter wet
    # "RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304" Snowmelt lysimeter 03/07/2025; 03/17/2025; 03/28/2025; 04/04/2025
    # "RI25-1128", "RI25-1130" Snow core 12/10/2024; Snow core post rain 12/12/2024

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Wade",
    start_date="2024-12-10",
    end_date="2024-12-14",
    endmember_ids=["RI25-1128", "RI25-1130", # Snow cores from Dec '24
                   #"RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304", # Snowmelt lysimeter
                   #"RI25-1306", # Soil water lysimeter wet
                   "RI25-1123", "RI25-1115", #"RI25-1305", # Soil water lysimeter dry 
                   "RI25-1126", "RI25-1031", "RI25-1090"],  #Baseflow
    title="Wade Dec. ROS (Dec 10–Dec 13, 2025)"
)

# Event B
# Wade 12/29 ROS event
# Potential endmembers: 
    # "RI25-1126", "RI25-1031", "RI25-1090", "RI25-1183", "RI25-1201", "RI25-1290" 12/06/2024 (good baseflow); potential baseflow 12/10/2024 + 12/28/2024; 03/04/2025; 03/11/2025; 03/03/2025
    # "RI25-1123", "RI25-1115", "RI25-1305" Soil lysimeter dry 12/17/2024; 2/10/2025; 04/04/2024
    # "RI25-1306" Soil water lysimeter wet
    # "RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304" Snowmelt lysimeter 03/07/2025; 03/17/2025; 03/28/2025; 04/04/2025
    # "RI25-1128", "RI25-1130" Snow core 12/10/2024; Snow core post rain 12/12/2024

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Wade",
    start_date="2024-12-28",
    end_date="2025-01-04",
    endmember_ids=["RI25-1128", "RI25-1130", # Snow cores from Dec '24
                   #"RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304", # Snowmelt lysimeter
                   #"RI25-1306", # Soil water lysimeter wet
                   "RI25-1123", "RI25-1115", #"RI25-1305", # Soil water lysimeter dry 
                   "RI25-1126", "RI25-1031", "RI25-1090"],  #Baseflow
    title="Wade Dec-Jan ROS (Dec 29–Jan 03, 2025)"
)

# Event D,E
# Wade 03/03 ROS event
# Potential endmembers: 
    # "RI25-1126", "RI25-1031", "RI25-1090", "RI25-1183", "RI25-1201", "RI25-1290" 12/06/2024 (good baseflow); potential baseflow 12/10/2024 + 12/28/2024; 03/04/2025; 03/11/2025; 03/03/2025
    # "RI25-1123", "RI25-1115", "RI25-1305" Soil lysimeter dry 12/17/2024; 2/10/2025; 04/04/2024
    # "RI25-1306" Soil water lysimeter wet
    # "RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304" Snowmelt lysimeter 03/07/2025; 03/17/2025; 03/28/2025; 04/04/2025
    # "RI25-1128", "RI25-1130" Snow core 12/10/2024; Snow core post rain 12/12/2024

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Wade",
    start_date="2025-03-03",
    end_date="2025-03-28",
    endmember_ids=["RI25-1229", # Snowmelt lysimeter
                   "RI25-1115", # Soil water lysimeter dry 
                   "RI25-1183", "RI25-1201", "RI25-1290"],  #Baseflow
    title="Wade Mar. ROS (Mar 04–Mar 23, 2025)"
)

# Event F
# Wade 03/26 ROS event
# Potential endmembers: 
    # "RI25-1126", "RI25-1031", "RI25-1090", "RI25-1183", "RI25-1201", "RI25-1290" 12/06/2024 (good baseflow); potential baseflow 12/10/2024 + 12/28/2024; 03/04/2025; 03/11/2025; 03/03/2025
    # "RI25-1123", "RI25-1115", "RI25-1305" Soil lysimeter dry 12/17/2024; 2/10/2025; 04/04/2024
    # "RI25-1306" Soil water lysimeter wet
    # "RI25-1227", "RI25-1229", "RI25-1301", "RI25-1304" Snowmelt lysimeter 03/07/2025; 03/17/2025; 03/28/2025; 04/04/2025
    # "RI25-1128", "RI25-1130" Snow core 12/10/2024; Snow core post rain 12/12/2024

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Wade",
    start_date="2025-03-25",
    end_date="2025-04-05",
    endmember_ids=["RI25-1301", "RI25-1304", # Snowmelt lysimeter
                   "RI25-1115", "RI25-1305", # Soil water lysimeter dry 
                   "RI25-1183", "RI25-1201", "RI25-1290"],  #Baseflow
    title="Wade freshet (Mar 26–Apr 04, 2025)"
)
# Out:
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Wade_Wade_Dec._ROS_Dec_10–Dec_13,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Wade_Wade_Dec-Jan_ROS_Dec_29–Jan_03,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Wade_Wade_Mar._ROS_Mar_04–Mar_23,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Wade_Wade_freshet_Mar_26–Apr_04,_2025.jpg
