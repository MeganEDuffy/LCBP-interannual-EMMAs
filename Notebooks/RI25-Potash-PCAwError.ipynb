# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_pca_error as ep
importlib.reload(ep)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

######################
# Potash RI25 events #
######################

# Event A
# Potash 12/10 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Potash",
    start_date="2024-12-10",
    end_date="2024-12-14",
    endmember_ids=["RI25-1127", "RI25-1114", # Snow cores from Dec '24
                   "RI25-1125", # Soil water lysimeter dry 12/18
                   "RI25-1109"],  #Baseflow 12/28
    title="Potash Dec. ROS (Dec 10–Dec 13, 2025)"
)

# Event B
# Potash 12/28 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Potash",
    start_date="2024-12-27",
    end_date="2025-01-04",
    endmember_ids=["RI25-1133", # Snow melt lysimeter 2/27
                   "RI25-1125", # Soil water lysimeter dry 12/18
                   "RI25-1109"],  #Baseflow 12/28
    title="Potash Dec-Jan. ROS (Dec 28–Jan 02, 2025)"
)

# Event C
# Potash 2/24 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Potash",
    start_date="2025-02-23",
    end_date="2025-02-28",
    endmember_ids=["RI25-1133", # Snowmelt lysimeter 2/27
                   "RI25-1125", "RI25-1132", # Soil water lysimeter dry 
                   "RI25-1109", "RI25-1131"],  #Baseflow
    title="Potash Feb. ROS (Feb 24–28, 2025)"
)

# Event D
# Potash 3/04 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Potash",
    start_date="2025-03-04",
    end_date="2025-03-21",
    endmember_ids=["RI25-1287", # Snowmelt lysimeter 3/19
                   "RI25-1286", # Soil water lysimeter dry 3/19
                   "RI25-1109", "RI25-1131"],  #Baseflow
    title="Potash Mar. spring melt (Mar 04–20, 2025)"
)
# Out:
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Potash_Potash_Dec._ROS_Dec_10–Dec_13,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Potash_Potash_Dec-Jan._ROS_Dec_28–Jan_02,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Potash_Potash_Feb._ROS_Feb_24–28,_2025.jpg
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Potash_Potash_Mar._spring_melt_Mar_04–20,_2025.jpg
