# %% [markdown]
# ## Plotting candidate end-members with improved tracer selection for RI23 events:

# %%
import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

####################
# Wade RI23 events #
####################

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   "RI23-5018", # Homeowner well groundwater March 2023
                   "RI23-5006", # Homeowner well groundwater March 2023
                   "RI22-0860", # Homeowner well groundwater 2022
                   "RI22-0859", # Homeowner well groundwater 2022
                   "RI23-1034", # Pre-event baseflow
                   "RI25-1111", # 2025 baseflow samples
                   "RI25-1126", # 2025 baseflow samples
                   "RI25-1183", # 2025 baseflow samples
                   "RI25-1201", # 2025 baseflow samples
                   "RI25-1290", # 2025 baseflow samples     
                   "RI23-5000", # SWL D February 15 2023
                   "RI23-5005", # Snowmelt lysimeter 02/15/2023
                   "RI23-1063", # Snowmelt lysimeter 3/28
                   "RI23-1098", # Snowmelt lysimeter 04/11/2023
                   "RI23-5009", # Soil water lysimeter sample
                   "RI23-5011", # Soil water lysimeter wet 4/12
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Wade",
    start_date="2023-02-08",
    end_date="2023-04-19",
    exploratory_ids=candidate_samples,
    title="Wade winter-to-spring"
)

# %%
#################
# FEB ROS at WB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   "RI23-5018", # Homeowner well groundwater March 2023
                   #"RI23-5006", # Homeowner well groundwater March 2023
                   #"RI22-0860", # Homeowner well groundwater 2022
                   #"RI22-0859", # Homeowner well groundwater 2022
                   #"RI23-1034", # Pre-event baseflow
                   #"RI25-1111", # 2025 baseflow samples
                   #"RI25-1126", # 2025 baseflow samples
                   #"RI25-1183", # 2025 baseflow samples
                   #"RI25-1201", # 2025 baseflow samples
                   #"RI25-1290", # 2025 baseflow samples     
                   "RI23-5000", # SWL D February 15 2023
                   "RI23-5005", # Snowmelt lysimeter 02/15/2023
                   #"RI23-1063", # Snowmelt lysimeter 3/28
                   #"RI23-1098", # Snowmelt lysimeter 04/11/2023
                   #"RI23-5009", # Soil water lysimeter sample
                   #"RI23-5011", # Soil water lysimeter wet 4/12
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Wade",
    start_date="2023-02-14",
    end_date="2023-02-20",
    exploratory_ids=candidate_samples,
    title="Wade February ROS"
)

# %%
#################
# MAR THM at WB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   "RI23-5018", # Homeowner well groundwater March 2023
                   #"RI23-5006", # Homeowner well groundwater March 2023
                   #"RI22-0860", # Homeowner well groundwater 2022
                   #"RI22-0859", # Homeowner well groundwater 2022
                   #"RI23-1034", # Pre-event baseflow 03/22/2023
                   #"RI25-1111", # 2025 baseflow samples
                   #"RI25-1126", # 2025 baseflow samples
                   #"RI25-1183", # 2025 baseflow samples
                   #"RI25-1201", # 2025 baseflow samples
                   #"RI25-1290", # 2025 baseflow samples     
                   #"RI23-5000", # SWL D February 15 2023
                   "RI23-5005", # Snowmelt lysimeter 02/15/2023
                   #"RI23-1063", # Snowmelt lysimeter 3/28
                   #"RI23-1098", # Snowmelt lysimeter 04/11/2023
                   "RI23-5009", # Soil water lysimeter 03/16/2023
                   #"RI23-5011", # Soil water lysimeter wet 4/12
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Wade",
    start_date="2023-03-21",
    end_date="2023-03-26",
    exploratory_ids=candidate_samples,
    title="Wade March thermal"
)

# %%
#################
# FRESHET at WB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   "RI23-5018", # Homeowner well groundwater March 2023
                   #"RI23-5006", # Homeowner well groundwater March 2023
                   #"RI22-0860", # Homeowner well groundwater 2022
                   #"RI22-0859", # Homeowner well groundwater 2022
                   #"RI23-1034", # Pre-event baseflow 03/22/2023
                   #"RI25-1111", # 2025 baseflow samples
                   #"RI25-1126", # 2025 baseflow samples
                   #"RI25-1183", # 2025 baseflow samples
                   #"RI25-1201", # 2025 baseflow samples
                   #"RI25-1290", # 2025 baseflow samples     
                   #"RI23-5000", # SWL D February 15 2023
                   #"RI23-5005", # Snowmelt lysimeter 02/15/2023
                   #"RI23-1063", # Snowmelt lysimeter 3/28
                   "RI23-1098", # Snowmelt lysimeter 04/11/2023
                   #"RI23-5009", # Soil water lysimeter 03/16/2023
                   "RI23-5011", # Soil water lysimeter wet 4/12
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Wade",
    start_date="2023-03-30",
    end_date="2023-04-15",
    exploratory_ids=candidate_samples,
    title="Wade final spring melt"
)
