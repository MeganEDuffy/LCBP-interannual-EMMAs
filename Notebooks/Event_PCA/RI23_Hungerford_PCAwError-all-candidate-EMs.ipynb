# %% [markdown]
# # Plotting candidate end-members with improved tracer selection for RI23 events:

# %%
import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

##########################
# Hungerford RI23 events #
##########################

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
    #"RI23-5008",         # Mark's well 03/2023
    "RI23-1001",         # Baseflow 02/09/2023
    "RI23-5003",         # SWLD 02/15/2023
    "RI23-5002",         # SML 02/15/2023
    #"RI23-1085",         # Baseflow 03/31/2023
    "RI23-5007",         # Soil water lysimeter dry 03/16/2023
    "RI23-1061",         # Snowmelt lysimeter 03/28/2023
    "RI23-5013",         # Soil water lysimeter wet 04/12/23
    "RI23-5014",         # Soil water lysimeter dry 04/12/23
    "RI23-5016",         # Precip 04/13/23
    "RI23-5017",         # Snowmelt lysimeter 04/12/2023 
    #"RI19-HB-SGW7-12",   # Shallow groundwater 2019
    #"RI19-HB-SGW7-8",    # Shallow groundwater 2019
    #"RI19-HB-SGW7-10"    # Shallow groundwater 2019
    "RI24-1259",         # 02/08/2024 baseflow
    "RI25-1033",         # 12/10/2024 baseflow
    "RI25-1110",         # 12/28/2024 baseflow
    "RI25-1149"          # 03/05/2025 baseflow
]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Hungerford",
    start_date="2023-02-08",
    end_date="2023-04-15",
    exploratory_ids=candidate_samples,
    title="Hungerford winter-to-spring"
)

# %%
#################
# FEB ROS at HB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers
analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

##########################
# Hungerford RI23 events #
##########################

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
    #"RI23-5008",         # Mark's well 03/2023
    #"RI23-1001",         # Baseflow 02/09/2023
    "RI23-5003",         # SWLD 02/15/2023
    "RI23-5002",          # SML 02/15/2023
    #"RI23-1085",         # Baseflow 03/31/2023
    #"RI23-5007",         # Soil water lysimeter dry 03/16/2023
    #"RI23-1061",         # Snowmelt lysimeter 03/28/2023
    #"RI24-1259",         # 02/08/2024 baseflow
    #"RI25-1033",         # 12/10/2024 baseflow
    "RI25-1110",         # 12/28/2024 baseflow
    #"RI25-1149"          # 03/05/2025 baseflow
]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Hungerford",
    start_date="2023-02-08",
    end_date="2023-02-12",
    exploratory_ids=candidate_samples,
    title="Hungerford Feb. ROS"
)

# %%
#################
# MAR THM at HB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers
analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

##########################
# Hungerford RI23 events #
##########################

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   #"RI23-1001", # Baseflow 02/09/2023 (labeled GW)
                   "RI23-1035", # 03/22/2023 Baseflow(pre-event)
                   #"RI23-5008", # Mark's well 2023
                   #"RI20-HB-DGW-Mark-1" # Mark's well 2020
                   #"RI22-0858", # Mark's well 03/17/2022
                   #"RI22-0864",
                   #"RI23-1085", #Baseflow 03/31/2023 removed for now
                   "RI23-5007", # SWLD
                   "RI23-1061"
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Hungerford",
    start_date="2023-03-21",
    end_date="2023-03-26",
    exploratory_ids=candidate_samples,
    title="Hungerford Mar. thermal"
)

# %%
#################
# FRESHET at HB #
#################

import importlib
import sys
from pathlib import Path
import pandas as pd

# Set up home path and working repo dir 
HOME = Path.home()
repo_dir = HOME / "OneDrive/git-repos/LCBP-interannual-EMMAs"

if str(repo_dir) not in sys.path:
    sys.path.append(str(repo_dir))

# Import EMMA module
import EMMA.event_emma as em  
import EMMA.event_pca_error as ep
importlib.reload(ep)
importlib.reload(em)

# Define data directory using relative path logic
data_dir = repo_dir / "Data/GrabSample_data"

# Load the full RI18 through RI25 dataset
# see join @ https://github.com/MeganEDuffy/LCBP-interannual-EMMAs/blob/main/Notebooks/Combining-all-years-RI.ipynb
df = pd.read_csv(data_dir / "RI18-25-joined.csv")

# Load just the RI23 dataset
#df = pd.read_csv(data_dir / "RI23-IC-ICP-isotope-toc-joined.csv")

# Analytical uncertainty for tracers
analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'Cu_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

##########################
# Hungerford RI23 events #
##########################

# Test candidate deep groundwater, baseflow, soil water, and meltwater
candidate_samples = [
                   "RI23-1001", # Baseflow 02/09/2023 (labeled GW)
                  #"RI23-1085", # Baseflow 03/31/23
                   #"RI23-5008", # Groundwater (Mark's well) 03/16/2023
                   #"RI20-HB-DGW-Mark-1" # Mark's well 2020
                   #"RI22-0858", # Mark's well 03/17/2022
                   #"RI22-0864", # Mark's well 07/27/2022
                   "RI23-5013", # Soil water lysimeter wet 04/12/23
                   "RI23-5017", # Snowmelt lysimeter 04/12/23
                   "RI23-1061" # Snowmelt lysimeter 03/28/23
                    ]

explore_results, pca_model, scaler_model = ep.plot_event_pca_explore_samples(
    data=df,
    site="Hungerford",
    start_date="2023-03-30",
    end_date="2023-04-04",
    exploratory_ids=candidate_samples,
    title="Hungerford spring melt (Mar 30 – April 03)"
)
