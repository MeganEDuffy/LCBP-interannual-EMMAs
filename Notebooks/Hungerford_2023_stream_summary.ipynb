# %%
# Steram summary plotting function lives here
source("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Functions/plot_stream_summary.R")

# 1. Overall time range
my_range <- as.POSIXct(c("2023-01-01", "2023-04-20"), tz = "UTC")

# 2. Storm event time range definintions
my_events <- list(
  start = c('2023-02-14', '2023-03-21', '2023-03-30'),
  end   = c('2023-02-20', '2023-03-26', '2023-04-15')
)

# 3. Call the steam summary plotting function
hungerford_plot <- plot_stream_summary(
  site_name      = "Hungerford",
  plot_range     = my_range,
  event_bounds   = my_events,
  q_file         = "/home//millieginty//OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/hb_q_chem_20211001-20230930.csv",
  exo_file       = "/home//millieginty//OneDrive/git-repos/cQ_analysis/cond-hydrograph-separation/newrnet/data/hungerford_2023_sC_2024-07-31.csv",
  grab_chem_file = "/home//millieginty//OneDrive/git-repos/EMMA/isco_metadata/LCBP_RI_sample_index/RI23-IC-ICP-isotope-toc-joined.csv",
  doc_file       = "/home//millieginty//OneDrive/git-repos/EMMA/data/newrnet-q-scan/DOC.DOC@Hungerford_Brook.20221001.csv",
  ic_sc_file     = "/home//millieginty//OneDrive/git-repos/LCBP-interannual-EMMAs/Data/GrabSample_data/RI23-ion-chromatography/RI23_IC_uS-totals.csv",
  q_lim        = c(0, 12),
  sc_lim       = c(0, 550),
  chem_lim     = c(0, 50)
)

print(hungerford_plot)
# Out:
# [1] "Rows in Q: 69948"
# [1] "Rows in EXO: 34885"
# [1] "Rows in Joined Data: 34885"
#              timestamp    q_cms      NO3         TP NO3_source TP_source     X
#                 <POSc>    <num>    <num>      <num>     <char>    <char> <int>
# 1: 2023-01-01 00:02:00 3.407217 3.687141 0.06262987     sensor    sensor     1
# 2: 2023-01-01 00:17:00 3.456883 3.682458 0.07644286     sensor    sensor     2
# 3: 2023-01-01 00:32:00 3.212604 3.689453 0.08717894     sensor    sensor     3
# 4: 2023-01-01 00:47:00 3.394864 3.710458 0.06194284     sensor    sensor     4
# 5: 2023-01-01 01:02:00 3.407217 3.705992 0.11045297     sensor    sensor     5
# 6: 2023-01-01 01:17:00 3.309102 3.731543 0.06797755     sensor    sensor     6
#              Timestamp     sC
#                 <char>  <num>
# 1: 2023-01-01 00:02:00 290.97
# 2: 2023-01-01 00:17:00 291.73
# 3: 2023-01-01 00:32:00 292.51
# 4: 2023-01-01 00:47:00 293.06
# 5: 2023-01-01 01:02:00 293.55
# 6: 2023-01-01 01:17:00 293.79
# ...
