# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_emma as em
importlib.reload(em)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

####################
# Potash RI25 events #
####################

# Step 1: PCA: Potash December ROS event
# Event A
# Potash 12/10 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

potash_decros_fractions_df, potash_decros_scaler, potash_decros_pca, potash_decros_endmembers_df = em.run_emma_event(
    data=df,
    site="Potash",
    start_date="2024-12-10 00:00:00",
    end_date="2025-01-04 00:00:00",
    endmember_ids=["RI25-1127", #"RI25-1114", # Snow cores from Dec '24
                   "RI25-1125", # Soil water lysimeter dry 12/18
                   "RI25-1109"],  #Baseflow 12/28
)

#potash_tracers = ['Ca_mg_L', 'Cl_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']
potash_tracers = ['Ca_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']

# Call the prediction function
potash_decros_predicted = em.predict_tracers_from_fractions(
    fractions_df=potash_decros_fractions_df,
    endmembers_df=potash_decros_endmembers_df,
    tracer_cols=potash_tracers
)

# Plot observed vs predicted tracer values
em.plot_observed_vs_predicted("Potash-Brook-December-2024-ROS", potash_decros_predicted, df, potash_tracers)

em.plot_emma_fractions_with_hydrograph(
    fractions_df= potash_decros_fractions_df,
    discharge_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Discharge.Discharge_Updated@Potash_Brook.20221001.csv",
    snowpack_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/Met_data/Potash_KBTV-GHCN-Daily-WY22-WY25.csv",
    snowpack_time_col="DATE",
    start_date="2024-12-10 00:00:00",
    end_date="2024-12-14 00:00:00",
    site="Potash",
    title="Potash Dec. ROS (Dec 10–13, 2025)"
)
# Out:
# ✅ Figure saved to output/EMMA-error-plots/Potash-Brook-December-2024-ROS.png

# %%
potash_decros_fractions_df
# Out:
#     Sample ID            Datetime    Site  Baseflow  Soil water lysimeter dry  \
# 0   RI25-1001 2024-12-10 09:00:00  Potash  1.000000              2.664535e-15
# 1   RI25-1002 2024-12-10 12:00:00  Potash  0.988852              7.259572e-03
# 2   RI25-1003 2024-12-10 15:00:00  Potash  0.821980              8.881957e-02
# 3   RI25-1004 2024-12-10 18:00:00  Potash  0.651580              2.478837e-01
# 4   RI25-1005 2024-12-10 21:00:00  Potash  0.539699              2.807064e-01
# 5   RI25-1006 2024-12-11 00:00:00  Potash  0.697374              1.894055e-01
# 6   RI25-1007 2024-12-11 03:00:00  Potash  0.904272              9.572844e-02
# 7   RI25-1008 2024-12-11 06:00:00  Potash  0.771212              1.277106e-01
# 8   RI25-1009 2024-12-11 09:00:00  Potash  0.855500              6.033032e-02
# 9   RI25-1010 2024-12-11 12:00:00  Potash  0.862980              1.330593e-01
# 10  RI25-1011 2024-12-11 15:00:00  Potash  0.831112              5.893028e-02
# ...

# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_emma as em
importlib.reload(em)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

######################
# Potash RI25 events #
######################

# Step 1: PCA: Potash Potash February ROS event
# Event C
# Potash 3/04 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

potash_febros_tracers, potash_febros_pca = em.plot_event_pca(
    data=df,
    site="Potash",
    start_date="2025-02-23 00:00:00",
    end_date="2025-02-28 00:00:00",
    endmember_ids=["RI25-1133", # Snowmelt lysimeter 2/27
                   "RI25-1132", # Soil water lysimeter dry 
                   "RI25-1131"],  #Baseflow
    title="PCA for Potash Feb. ROS (Feb 24–28, 2025)"
)

# Step 2: EMMA: Potash February ROS event
# Event C
# Potash 2/24 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

potash_febros_fractions_df, potash_febros_scaler, potash_febros_pca, potash_febros_endmembers_df = em.un_emma_event(
    data=df,
    site="Potash",
    start_date="2025-02-23 00:00:00",
    end_date="2025-02-28 00:00:00",
    endmember_ids=["RI25-1133", # Snowmelt lysimeter 2/27
                   "RI25-1132", # Soil water lysimeter dry 
                   "RI25-1131"],  #Baseflow
)

#potash_tracers = ['Ca_mg_L', 'Cl_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']
potash_tracers = ['Ca_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']

# Call the prediction function
potash_decros_predicted = em.predict_tracers_from_fractions(
    fractions_df=potash_decros_fractions_df,
    endmembers_df=potash_decros_endmembers_df,
    tracer_cols=potash_tracers
)

# Plot observed vs predicted tracer values
em.plot_observed_vs_predicted("Potash-Brook-February-2025-ROS", potash_decros_predicted, df, potash_tracers)

# Plot EMMA with hydrograph
em.plot_emma_fractions_with_hydrograph(
    fractions_df= potash_febros_fractions_df,
    discharge_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Discharge.Discharge_Updated@Potash_Brook.20221001.csv",
    snowpack_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/Met_data/Potash_KBTV-GHCN-Daily-WY22-WY25.csv",
    snowpack_time_col="DATE",
    start_date="2025-02-23 00:00:00",
    end_date="2025-02-28 00:00:00",
    site="Potash",
    title="Potash Feb. ROS (Feb 24–28, 2025)"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 47
#      26 potash_febros_tracers, potash_febros_pca = em.plot_event_pca(
#      27     data=df,
#      28     site="Potash",
#    (...)
#      34     title="PCA for Potash Feb. ROS (Feb 24–28, 2025)"
#      35 )
#      37 # Step 2: EMMA: Potash February ROS event
#      38 # Event C
#      39 # Potash 2/24 ROS event
#    (...)
#      44     # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
#      45     # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13
# ---> 47 potash_febros_fractions_df, potash_febros_scaler, potash_febros_pca, potash_febros_endmembers_df = em.un_emma_event(
#      48     data=df,
#      49     site="Potash",
#      50     start_date="2025-02-23 00:00:00",
#      51     end_date="2025-02-28 00:00:00",
# ...

# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_emma as em
importlib.reload(em)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

######################
# Potash RI25 events #
######################

# Step 1: PCA: Potash March ROS to final melt event
# Event E, F
# Potash 3/04 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

potash_marros_tracers, potash_marros_pca = em.plot_event_pca(
    data=df,
    site="Potash",
    start_date="2025-03-03 00:00:00",
    end_date="2025-03-20 00:00:00",
    endmember_ids=["RI25-1287", # Snowmelt lysimeter 2/27
                   "RI25-1286", # Soil water lysimeter dry 
                   "RI25-1109"],  #Baseflow
    title="PCA for Potash Feb. ROS (Feb 24–28, 2025)"
)

# Step 2: EMMA: Potash March ROS to final melt event
# Event E,F
# Potash 3/04 ROS event
# Potential endmembers: 
    # RI25-1125 12/18 Soil lysimeter dry; RI25-1132 2/27; RI25-1286 3/19
    # Soil water lysimeter wet (no wet site @ Potash)
    # RI25-1133 2/27 Snowmelt lysimeter; RI25-1200 3/7 SML; RI25-1287 3/19 SML
    # RI25-1127 12/10 Snow core; RI25-1114 12/28 Snow core
    # Baseflow: RI25-1109 12/28; RI25-1131 2/24 pre-ISCO grab; RI25-1181 3/4/2025 pre-ISCO grab; RI25-1203 pre-ISCO grab 3/13

potash_marros_fractions_df, potash_marros_scaler, potash_marros_pca, potash_marros_endmembers_df = em.run_emma_event(
    data=df,
    site="Potash",
    start_date="2025-03-03 00:00:00",
    end_date="2025-03-20 00:00:00",
    endmember_ids=["RI25-1287", # Snowmelt lysimeter 2/27
                   "RI25-1286", # Soil water lysimeter dry 
                   "RI25-1109"],  #Baseflow
)

potash_tracers = ['Ca_mg_L', 'Cl_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']

# Call the prediction function
potash_marros_predicted = em.predict_tracers_from_fractions(
    fractions_df=potash_marros_fractions_df,
    endmembers_df=potash_marros_endmembers_df,
    tracer_cols=potash_tracers
)

# Plot observed vs predicted tracer values
em.plot_observed_vs_predicted("Potash-Brook-Mar-2025-ROS-melt", potash_marros_predicted, df, potash_tracers)

# Plot EMMA with hydrograph
em.plot_emma_fractions_with_hydrograph(
    fractions_df= potash_marros_fractions_df,
    discharge_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/StreamSensor_data/Discharge.Discharge_Updated@Potash_Brook.20221001.csv",
    snowpack_csv="/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Data/Met_data/Potash_KBTV-GHCN-Daily-WY22-WY25.csv",
    snowpack_time_col="DATE",
    start_date="2025-03-04 00:00:00",
    end_date="2025-03-20 00:00:00",
    site="Potash",
    title="Potash Mar ROS-final melt (Mar 04–20, 2025)"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 60
#      57 potash_tracers = ['Ca_mg_L', 'Cl_mg_L', 'K_mg_L', 'Na_mg_L', 'Mg_mg_L', 'dD', 'd18O']
#      59 # Call the prediction function
# ---> 60 potash_marros_predicted = em.predict_tracers_from_fractions(
#      61     fractions_df=potash_marros_fractions_df,
#      62     endmembers_df=potash_marros_endmembers_df,
#      63     tracer_cols=potash_tracers
#      64 )
#      66 # Plot observed vs predicted tracer values
#      67 em.plot_observed_vs_predicted("Potash-Brook-Mar-2025-ROS-melt", potash_marros_predicted, df, potash_tracers)
#
# File ~/OneDrive/git-repos/LCBP-interannual-EMMAs/EMMA/event_emma.py:290, in predict_tracers_from_fractions(fractions_df, endmembers_df, tracer_cols)
#     287 endmember_types = [col for col in fractions_df.columns if col in endmembers_df['Type'].unique()]
# ...

# %%
# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI25/RI25-IC-ICP-isotope-joined.csv")

df.loc[
    df['Sample ID'] == 'RI25-1024',
    potash_tracers
]
# Out:
#       Ca_mg_L  Cl_mg_L    K_mg_L    Na_mg_L    Mg_mg_L     dD    d18O
# 23  53.337536  512.394  5.108416  283.93492  17.528014 -73.68 -10.827
