# %% [markdown]
# # new formulation for propagating error as in Genereux (1998), in the U-space

# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")  

import importlib
import pandas as pd
import EMMA.event_pca_error as ep
importlib.reload(ep)

# Load the full RI25 dataset
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI23/RI23-IC-ICP-isotope-toc-joined-Wade.csv")

# Analytical uncertainty for tracers

analytical_precision_ri23 = {
    'Ca_mg_L': 0.05,  # mg/L
    'Si_mg_L': 0.05,  # mg/L
    'Mg_mg_L': 0.05,  # mg/L
    'K_mg_L': 0.05,  # mg/L
    'Na_mg_L': 0.05,  # mg/L
    'Cl_mg_L': 0.10,  # mg/L
    'd18O': 0.1,      # permille
    'dD': 0.1    # permille
}

####################
# Wade RI23 events #
####################

# Event A
# Wade February ROS event
# Endmembers: 
    # RI23-5018 Groundwater Bear Pond 03/10/23
    # RI23-5006 Groundwater High Pond 03/01/23 (could be 03/10/23, doesn't really matter)
    # RI23-5000 Soil water lysimeter dry 02/15/23
    # RI23-5005 Snowmelt lysimeter 2/15
    # RI23-1032 Baseflow (pre-event 2/17, really post event..)

ep.plot_event_pca_with_avgEM(
    data=df,
    site="Wade",
    start_date="2023-02-14",
    end_date="2023-02-20",
    endmember_ids=["RI23-5018", "RI23-5006", "RI23-5000", "RI23-5005"],  # Removed RI23-1032 for now
    title="D. Wade Feb. ROS (Feb 14–20)"
)

stats_em, pca_model, scaler_model = ep.plot_event_pca_with_error(
    data=df,
    site="Wade",
    start_date="2023-02-14",
    end_date="2023-02-20",
    endmember_ids=["RI23-5018", "RI23-5006", "RI23-5000", "RI23-5005"],
    analytical_dict=analytical_precision_ri23, # Pass your dictionary here
    title="D. Wade Feb. ROS (Feb 14–20)"
)

# Now 'stats_em' contains your PC1_err and PC2_err for each endmember!
print(stats_em[['Type', 'PC1_err', 'PC2_err']])
# Out:
# Saved plot to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Wade_D._Wade_Feb._ROS_Feb_14–20.jpg
#                        Type    PC1_err    PC2_err
# 0  Soil water lysimeter dry   0.627339   0.699760
# 1        Snowmelt lysimeter   0.627339   0.699760
# 2               Groundwater  28.687016  24.615411

# %%
import sys
sys.path.append("/home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/")   

import importlib
import pandas as pd
import EMMA.event_pca_error as ep
importlib.reload(ep)

# Load data
df = pd.read_csv("/home/millieginty/OneDrive/git-repos/EMMA/data/newrnet-chemistry/RI23/RI23-IC-ICP-isotope-toc-joined-Wade.csv")

# Analytical uncertainty
analytical_precision_ri23 = {
    'Ca_mg_L': 0.05, 'Si_mg_L': 0.05, 'Mg_mg_L': 0.05, 
    'K_mg_L': 0.05, 'Na_mg_L': 0.05, 'Cl_mg_L': 0.10, 
    'd18O': 0.1, 'dD': 0.1
}

# Run the PCA with Error Propagation
# This will display the plot AND return the uncertainty values
stats_em, pca_model, scaler_model = ep.plot_event_pca_with_error(
    data=df,
    site="Wade",
    start_date="2023-02-14",
    end_date="2023-02-20",
    endmember_ids=["RI23-5018", "RI23-5006", "RI23-5000", "RI23-5005"],
    analytical_dict=analytical_precision_ri23,
    title="D. Wade Feb. ROS (Feb 14–20)"
)

# Display the propagated PC uncertainty
print("\n--- Propagated PC Uncertainties (W values for Genereux 1998) ---")
print(stats_em[['Type', 'PC1_err', 'PC2_err']])
# Out:
# --- Propagated PC Uncertainties (W values for Genereux 1998) ---
#                        Type    PC1_err    PC2_err
# 0  Soil water lysimeter dry   0.627339   0.699760
# 1        Snowmelt lysimeter   0.627339   0.699760
# 2               Groundwater  28.687016  24.615411
