# %%
library(fs)
library(ggplot2)
library(GGally)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_tracer_bivariate_grid.R"))

data_dir   <- file.path(repo_dir, "Data/")
output_dir <- file.path(repo_dir, "Output/Tracer-selection/")
chem_file  <- file.path(data_dir, "GrabSample_data", "RI23-IC-ICP-isotope-toc-joined.csv")

# 1. Run for Hungerford Brook
hungerford_results <- plot_tracer_bivariate_grid(
  chem_data_file = chem_file,
  site_name      = "Hungerford",
  output_dir     = output_dir,
  base_font_size = 10
)

print(hungerford_results$plot)
cat("Hungerford Streamwater Sample Count (n):", hungerford_results$n_samples, "\n")

# 2. Run for Wade Brook
wade_results <- plot_tracer_bivariate_grid(
  chem_data_file = chem_file,
  site_name      = "Wade",
  output_dir     = output_dir,
  base_font_size = 10
)

print(wade_results$plot)
cat("Wade Streamwater Sample Count (n):", wade_results$n_samples, "\n")
# Out:
# ℹ️ Site: Hungerford | Evaluated 31 total streamwater rows with pairwise completeness.
#
# ✅ Bivariate grid successfully saved to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Tracer-selection//Hungerford_tracer_bivariate_grid.jpg
# Hungerford Streamwater Sample Count (n): 31
# ℹ️ Site: Wade | Evaluated 56 total streamwater rows with pairwise completeness.
#
# ✅ Bivariate grid successfully saved to: /home/millieginty/OneDrive/git-repos/LCBP-interannual-EMMAs/Output/Tracer-selection//Wade_tracer_bivariate_grid.jpg
# plot without title
# Wade Streamwater Sample Count (n): 56
# plot without title

# %%
library(fs)
library(ggplot2)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_tracer_correlation_matrix.R"))

data_dir   <- file.path(repo_dir, "Data/")
output_dir <- file.path(repo_dir, "Output/Tracer-selection/")
chem_file  <- file.path(data_dir, "GrabSample_data", "RI23-IC-ICP-isotope-toc-joined.csv")

# 1. Run Correlation Matrix for Hungerford Brook
hungerford_cor <- plot_tracer_correlation_matrix(
  chem_data_file = chem_file,
  site_name      = "Hungerford",
  output_dir     = output_dir,
  base_font_size = 25
)

print(hungerford_cor$plot)

# 2. Run Correlation Matrix for Wade Brook
wade_cor <- plot_tracer_correlation_matrix(
  chem_data_file = chem_file,
  site_name      = "Wade",
  output_dir     = output_dir,
  base_font_size = 25
)

print(wade_cor$plot)
# Out:
# ℹ️ Site: Hungerford | Computing correlation matrix for n = 31 streamwater samples.
#
# ℹ️ Site: Wade | Computing correlation matrix for n = 56 streamwater samples.
# plot without title
# plot without title

# %%
library(fs)
library(ggplot2)
library(tidyverse)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_hooper_pca_residuals.R"))

data_dir   <- file.path(repo_dir, "Data/")
output_dir <- file.path(repo_dir, "Output/Tracer-selection/")
chem_file  <- file.path(data_dir, "GrabSample_data", "RI23-IC-ICP-isotope-toc-joined.csv")

# Define tracer list 
target_tracers <- c("Mn_mg_L", "Ca_mg_L", "Mg_mg_L", "Na_mg_L", "Cl_mg_L", "Si_mg_L", "dD", "d18O", "SO4_mg_L", "K_mg_L", "Cu_mg_L", "P_mg_L")
# F excluded because we had only 60% data coverage for the Hungerford sample set

# Run residual analysis for Hungerford Brook across 1D through 5D mixing spaces
plot_hooper_pca_residuals(
  chem_data_file = chem_file,
  site_name      = "Hungerford",
  tracer_cols    = target_tracers,
  dimensions     = c(1, 2, 3, 4, 5, 6),
  output_dir     = output_dir,
  base_font_size = 14
)
# Out:
# ℹ️ Site: Hungerford | Running Hooper PCA residual analysis on n = 25 complete streamwater rows across dimensions: 1, 2, 3, 4, 5, 6.
# plot without title

# %%
library(fs)
library(ggplot2)
library(tidyverse)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")
source(file.path(repo_dir, "Functions/plot_hooper_pca_residuals.R"))

data_dir   <- file.path(repo_dir, "Data/")
output_dir <- file.path(repo_dir, "Output/Tracer-selection/")
chem_file  <- file.path(data_dir, "GrabSample_data", "RI23-IC-ICP-isotope-toc-joined.csv")

# Define tracer list 
target_tracers <- c("Mn_mg_L","Cu_mg_L", "P_mg_L", "Cl_mg_L", "SO4_mg_L", "Ca_mg_L", "Mg_mg_L", "Na_mg_L", "dD", "d18O", "DOC_mg_L", "K_mg_L")

# Run residual analysis for Wade Brook across 1D through 5D mixing spaces
plot_hooper_pca_residuals(
  chem_data_file = chem_file,
  site_name      = "Wade",
  tracer_cols    = target_tracers,
  dimensions     = c(1, 2, 3, 4, 6),
  output_dir     = output_dir,
  base_font_size = 14
)
# Out:
# ℹ️ Site: Wade | Running Hooper PCA residual analysis on n = 42 complete streamwater rows across dimensions: 1, 2, 3, 4, 6.
# plot without title

# %%
library(fs)

# Set directories
home_dir <- Sys.getenv("HOME")
repo_dir <- file.path(home_dir, "OneDrive/git-repos/LCBP-interannual-EMMAs")

# Source both functions
source(file.path(repo_dir, "Functions/plot_tracer_correlation_matrix.R"))
source(file.path(repo_dir, "Functions/get_tracer_coverage.R"))

data_dir  <- file.path(repo_dir, "Data/")
chem_file <- file.path(data_dir, "GrabSample_data", "RI23-IC-ICP-isotope-toc-joined.csv")

# 1. Get coverage for Hungerford Brook
hungerford_coverage <- get_tracer_coverage(chem_file, "Hungerford")
print("--- Hungerford Tracer Coverage ---")
print(hungerford_coverage)

# 2. Get coverage for Wade Brook
wade_coverage <- get_tracer_coverage(chem_file, "Wade")
print("--- Wade Tracer Coverage ---")
print(wade_coverage)
# Out:
# [1] "--- Hungerford Tracer Coverage ---"
#          Site   Tracer Total_Samples Valid_Samples Coverage_Pct
# 1  Hungerford       dD            31            31    100.00000
# 2  Hungerford     d18O            31            31    100.00000
# 3  Hungerford  Cl_mg_L            31            29     93.54839
# 4  Hungerford SO4_mg_L            31            29     93.54839
# 5  Hungerford DOC_mg_L            31            29     93.54839
# 6  Hungerford  Fe_mg_L            31            25     80.64516
# 7  Hungerford  Mn_mg_L            31            25     80.64516
# 8  Hungerford  Cu_mg_L            31            25     80.64516
# 9  Hungerford  Zn_mg_L            31            25     80.64516
# 10 Hungerford  Si_mg_L            31            25     80.64516
# 11 Hungerford   K_mg_L            31            25     80.64516
# 12 Hungerford   P_mg_L            31            25     80.64516
# 13 Hungerford  Mg_mg_L            31            25     80.64516
# 14 Hungerford  Na_mg_L            31            25     80.64516
# 15 Hungerford  Al_mg_L            31            25     80.64516
# 16 Hungerford  Ca_mg_L            31            25     80.64516
# 17 Hungerford   F_mg_L            31            19     61.29032
# [1] "--- Wade Tracer Coverage ---"
#    Site   Tracer Total_Samples Valid_Samples Coverage_Pct
# 1  Wade DOC_mg_L            56            54     96.42857
# 2  Wade  Cl_mg_L            56            53     94.64286
# 3  Wade SO4_mg_L            56            53     94.64286
# 4  Wade       dD            56            51     91.07143
# 5  Wade     d18O            56            51     91.07143
# 6  Wade  Fe_mg_L            56            48     85.71429
# 7  Wade  Mn_mg_L            56            48     85.71429
# 8  Wade  Cu_mg_L            56            48     85.71429
# 9  Wade  Zn_mg_L            56            48     85.71429
# 10 Wade  Si_mg_L            56            48     85.71429
# 11 Wade   K_mg_L            56            48     85.71429
# 12 Wade   P_mg_L            56            48     85.71429
# 13 Wade  Mg_mg_L            56            48     85.71429
# 14 Wade  Na_mg_L            56            48     85.71429
# 15 Wade  Al_mg_L            56            48     85.71429
# 16 Wade  Ca_mg_L            56            48     85.71429
